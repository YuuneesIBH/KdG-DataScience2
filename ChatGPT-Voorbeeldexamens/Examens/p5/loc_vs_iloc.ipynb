# %% [markdown]
# # The difference between loc and iloc

# %%
import pandas as pd
rides = {"Ride Name" : ["Titan", "New Texas Giant", "Batman", "Mr Freeze", "Shockwave"],
         "Inversions" : [0, 0, 5, 1, 2],
         "Top Speed (mph)" : [85, 65, 50, 70, 60],
         "Height (ft)" : [245, 153, 105, 218, 116]}
df = pd.DataFrame(data=rides)

# %%
print(df)
# Out:
#          Ride Name  Inversions  Top Speed (mph)  Height (ft)
# 2           Batman           5               50          105
# 4        Shockwave           2               60          116
# 1  New Texas Giant           0               65          153
# 3        Mr Freeze           1               70          218
# 0            Titan           0               85          245

# %%
print(df.loc[2])
# Out:
# Ride Name          Batman
# Inversions              5
# Top Speed (mph)        50
# Height (ft)           105
# Name: 2, dtype: object

# %%
print(df.iloc[-1])
# Out:
# Ride Name          Titan
# Inversions             0
# Top Speed (mph)       85
# Height (ft)          245
# Name: 0, dtype: object

# %%
import seaborn as sns
import pandas as pd
df = sns.load_dataset('iris')
print(df.head(30))
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...
